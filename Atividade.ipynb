# %% [markdown]
# <a href="https://colab.research.google.com/github/marcoseadr/Pos-graduacao-Big-Data/blob/main/Atividade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request  

texto = []

f = open('/Biblia_Sagrada.txt','r')  
for line in f:
    texto.append(line)

for i in range(len(texto)):
    texto[i] = texto[i].lower() 
    texto[i] = texto[i].replace('\n','')
    texto[i] = texto[i].replace('.','')
    texto[i] = texto[i].replace(',','')
    texto[i] = texto[i].replace('(','')
    texto[i] = texto[i].replace(')','')
    texto[i] = texto[i].replace('?','')
    texto[i] = texto[i].replace('\'','')

# %%
mydict = {}                             # crie um dicionário vazio

for line in texto:

  line = line.lower()                   # converte para lower(minusculo)
  words = line.split()                  # separa cada palavra
#  print(words)

  for word in words:                      # para cada palavra em words
    if word not in mydict.keys():         # se palavra não está no dicionário 
      mydict[word] = 1                    # acrescenta a word com o valor 1
    else:                                 # se a entrada já existe 
      mydict[word] =  mydict[word] + 1    # apenas soma 1 ao valor já existente

print(mydict)
# Out:
# {'bíblia': 1, 'sagrada': 10, 'tradução:': 1, 'joão': 136, 'ferreira': 1, 'de': 25097, 'almeida': 1, 'edição': 1, 'revista': 7, 'e': 37921, 'corrigida': 1, 'índice': 1, 'antigo': 11, 'testamento': 7, 'gênesis': 2, 'êxodo': 2, 'levítico': 3, 'números': 3, 'deuteronômio': 2, 'josué': 195, 'juízes': 46, 'rute': 13, 'i': 12, 'samuel': 168, 'ii': 11, 'reis': 367, 'crônicas': 112, 'esdras': 29, 'neemias': 10, 'ester': 49, 'jó': 58, 'salmos': 7, 'provérbios': 11, 'eclesiastes': 2, 'cântico': 35, 'dos': 4762, 'cânticos': 32, 'isaías': 38, 'jeremias': 141, 'lamentações': 9, 'ezequiel': 4, 'daniel': 75, 'oséias': 17, 'joel': 20, 'amós': 9, 'obadias': 21, 'jonas': 25, 'miquéias': 4, 'naum': 5, 'habacuque': 4, '»gênesis': 50, '[1]': 65, '1': 1189, 'no': 3932, 'princípio': 88, 'criou': 30, 'deus': 3945, 'os': 14101, 'céus': 200, 'a': 25332, 'terra': 2655, '2': 1189, 'era': 991, 'sem': 447, 'forma': 42, 'vazia;': 3, 'havia': 620, 'trevas': 130, 'sobre': 2761, 'face': 164, 'do': 10234, 'abismo': 35, 'mas': 3188, 'o': 26488, 'espírito': 557, 'pairava': 1, 'das': 1568, 'águas': 313, '3': 1188, 'disse': 1234, 'deus:': 175, 'haja': 110, 'luz': 298, 'houve': 154, '4': 1184, 'viu': 185, 'que': 21309, 'boa;': 2, 'fez': 809, 'separação': 14, 'entre': 962, 'as': 5818, '5': 1180, 'chamou': 153, 'à': 2252, 'dia': 1441, 'às': 357, 'noite': 284, 'foi': 1293, 'tarde': 115, 'manhã': 164, 'primeiro': 244, '6': 1173, 'um': 3762, 'firmamento': 21, 'meio': 683, '7': 1162, 'pois': 3353, 'separou': 15, 'estavam': 466, 'debaixo': 275, 'por': 4351, 'cima': 166, 'assim': 2034, '8': 1150, 'ao': 4443, 'céu': 464, 'segundo': 829, '9': 1134, 'ajuntem-se': 2, 'num': 199, 'só': 355, 'lugar': 773, 'estão': 539, 'apareça': 5, 'elemento': 2, 'seco': 13, '10': 1118, 'ajuntamento': 11, 'mares': 18, 'isso': 776, 'bom': 189, '11': 1098, 'produza': 7, 'relva': 14, 'ervas': 11, 'dêem': 15, 'semente': 52, 'árvores': 70, 'frutíferas': 5, 'suas': 1625, 'espécies': 13, 'fruto': 173, 'tenha': 123, 'em': 6211, 'si': 401, 'sua': 3427, '12': 1073, 'produziu': 6, 'davam': 27, 'tinha': 693, '13': 1048, 'terceiro': 118, '14': 1010, 'luminares': 4, 'para': 8514, 'fazerem': 45, 'noite;': 27, 'sejam': 169, 'eles': 1692, 'sinais': 76, 'estações': 2, 'dias': 872, 'anos;': 65, '15': 978, 'sirvam': 11, 'alumiar': 7, '16': 947, 'dois': 507, 'grandes': 184, 'luminares:': 1, 'luminar': 2, 'maior': 116, 'governar': 7, 'menor': 44, 'também': 2160, 'estrelas': 42, '17': 919, 'pôs': 191, '18': 874, 'fazer': 374, '19': 828, 'quarto': 79, '20': 805, 'produzam': 3, 'cardumes': 1, 'seres': 42, 'viventes;': 7, 'voem': 1, 'aves': 101, 'acima': 40, 'da': 6729, '21': 764, 'monstros': 3, 'marinhos': 3, 'todos': 2331, 'viventes': 44, 'se': 6952, 'arrastavam': 1, 'quais': 411, 'produziram': 1, 'abundantemente': 19, 'espécies;': 1, 'toda': 1118, 'ave': 29, 'voa': 3, 'espécie': 38, '22': 716, 'então': 2536, 'abençoou': 51, 'dizendo:': 1036, 'frutificai': 4, 'multiplicai-vos': 4, 'enchei': 7, 'mares;': 7, 'multipliquem-se': 2, '23': 658, 'quinto': 45, '24': 612, 'espécies:': 1, 'animais': 161, 'domésticos': 9, 'répteis': 14, 'selvagens': 5, '25': 578, '26': 533, 'façamos': 12, 'homem': 1530, 'nossa': 197, 'imagem': 63, 'conforme': 432, 'semelhança;': 2, 'domine': 5, 'ele': 3593, 'peixes': 38, 'mar': 352, 'todo': 1474, 'réptil': 12, 'arrasta': 9, '27': 505, 'imagem;': 1, 'criou;': 4, 'mulher': 658, '28': 464, 'lhes': 834, 'disse:': 839, 'multiplicai-vos;': 2, 'sujeitai-a;': 1, 'dominai': 1, 'arrastam': 5, '29': 431, 'disse-lhes': 61, 'mais:': 46, 'eis': 1185, 'vos': 1614, 'tenho': 397, 'dado': 141, 'todas': 996, 'produzem': 4, 'acham': 20, 'bem': 597, 'como': 3905, 'há': 917, 'dê': 50, 'semente;': 3, 'ser-vos-ão': 1, 'mantimento': 38, '30': 398, 'ser': 433, 'vivente': 26, 'verdes': 13, '31': 370, 'tudo': 796, 'quanto': 527, 'fizera': 104, 'muito': 354, 'sexto': 32, '[2]': 61, 'foram': 721, 'acabados': 2, 'com': 4962, 'seu': 3716, 'exército': 213, 'ora': 762, 'havendo': 137, 'completado': 1, 'sétimo': 109, 'obra': 286, ' ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

df = pd.DataFrame(mydict.items(),  columns=['word', 'count']).sort_values('count',ascending=False)
df = df[df['count'] > 3000]
#df = df.iloc[ np.int(len(df)/2) - 10 : np.int(len(df)/2) + 10 ] # para livros ou textos com muitos termos limita a um número mínimo de termos

plt.figure(figsize=(24,10))
mpl.style.use(['seaborn'])
sns.barplot(x=df.word,y=df['count'])
plt.xticks(rotation=90) 

plt.show()
